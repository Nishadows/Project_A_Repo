# %%
import pandas as pd

proj_df = pd.read_excel("ACS_17_5YR_S1501.xls")

proj_df.head()
# Out:
#                             Subject Northeast Region Total Estimate  \
# 0                            Region                Northeast Region
# 1                            Gender                           Total
# 2          Estimate/Margin of Error                        Estimate
# 3         Population 18 to 24 years                       5,421,107
# 4    Less than high school graduate                         630,304
#
#   Northeast Region  Margin of Error Northeast Region Percent Estimate  \
# 0                  Northeast Region                  Northeast Region
# 1                               NaN                           Percent
# 2                   Margin of Error                          Estimate
# 3                          +/-2,144                               (X)
# 4                          +/-5,732                             11.6%
#
#   Northeast Region  Margin of Error.1 Northeast Region Male Estimate  \
# ...

# %%
proj_df.dtypes
# Out:
# GEO.id                    object
# GEO.id2                   object
# GEO.display-label         object
# POPGROUP.id               object
# POPGROUP.display-label    object
# EST_VC03                  object
# MOE_VC03                  object
# EST_VC04                  object
# MOE_VC04                  object
# EST_VC05                  object
# MOE_VC05                  object
# EST_VC06                  object
# MOE_VC06                  object
# EST_VC07                  object
# MOE_VC07                  object
# EST_VC11                  object
# MOE_VC11                  object
# EST_VC13                  object
# MOE_VC13                  object
# EST_VC30                  object
# MOE_VC30                  object
# EST_VC31                  object
# MOE_VC31                  object
# EST_VC32                  object
# MOE_VC32                  object
# EST_VC33                  object
# MOE_VC33                  object
# EST_VC36                  object
# ...
